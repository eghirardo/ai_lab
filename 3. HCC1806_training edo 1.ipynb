# %%
#We import the necessary libreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict, validation_curve, learning_curve
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
import umap.umap_ as umap
import tensorflow as tf

# %%
df_seq_pathHFiltNorm = '../ai_lab/SmartSeq/HCC1806_SmartS_Filtered_Normalised_3000_Data_train.txt'
df_seq_HFiltNorm = pd.read_csv(df_seq_pathHFiltNorm, delimiter=' ')

# %%
df_seq_HFiltNorm.head()
df_seq_HFiltNorm.shape
# Out:
# (3000, 182)

# %%
df_seq_HfiltNormT = df_seq_HFiltNorm.T
df_seq_HfiltNormT.head()
# Out:
#                                                     DDIT4  ANGPTL4  CALML5  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       48       0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   8739     2101      55
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  13098    14032       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   2880      356       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...   7777     5661    4383
#
#                                                     KRT14  CCNB1  IGFBP3  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    321    298      82
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...     96   1824    1938
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0   1616     247
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   6211      3    3430
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0    145    4618
#
#                                                     AKR1C2  KRT6A  NDRG1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    6250    634      0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      62      0    522
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     430    907    348
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      79   1953    592
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     246     85    206
#
#                                                     KRT4  ...  MST1R  ZYG11A  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...     0  ...     78      10
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   413  ...    279       0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     0  ...    311       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   176  ...    125       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     0  ...    268       1
#
#                                                     NRG1  RBMS3  VCPIP1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...   136      0       0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   264      0     134
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...    38      0       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...    16      0       4
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...    25      0       0
#
#                                                     LINC02693  OR8B9P  NEAT1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...         29       0     29
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...         68       0    213
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...          0       0     92
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...          1       0      1
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...          0       0    128
#
#                                                     ZDHHC23  ODAD2
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...        0      0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...        0      0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...        0      0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...        0      0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...        0      0
#
# [5 rows x 3000 columns]

# %%
#we now add the target variable
df_metaH_path = '../ai_lab/SmartSeq/HCC1806_SmartS_MetaData.tsv'
df_metaH = pd.read_csv(df_metaH_path, delimiter='\t')
df_metaH.set_index('Filename', inplace=True)

def add_target_column(data, metadata_path, target_column_name, target_category):
    df_meta = pd.read_csv(metadata_path, delimiter='\t')
    df_meta.set_index('Filename', inplace=True)
    merged_transition = pd.merge(data, df_meta[target_column_name], left_index=True, right_index=True)
    dummy_variables = pd.get_dummies(merged_transition[target_column_name], prefix='category').astype('int')
    
    # Set the target category to 1 and the others to 0
    dummy_variables['Target'] = dummy_variables[target_category]
    dummy_variables.drop(columns=[col for col in dummy_variables.columns if col != 'Target'], inplace=True)
    
    merged_data = pd.concat([merged_transition, dummy_variables], axis=1)
    merged_data.drop(columns=[target_column_name], inplace=True)
    return merged_data

# %%
merged = add_target_column(df_seq_HfiltNormT, df_metaH_path, 'Condition', 'category_Normo')

# %%
merged.head()
# Out:
#                                                     DDIT4  ANGPTL4  CALML5  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       48       0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   8739     2101      55
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  13098    14032       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   2880      356       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...   7777     5661    4383
#
#                                                     KRT14  CCNB1  IGFBP3  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    321    298      82
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...     96   1824    1938
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0   1616     247
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   6211      3    3430
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0    145    4618
#
#                                                     AKR1C2  KRT6A  NDRG1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    6250    634      0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      62      0    522
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     430    907    348
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      79   1953    592
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     246     85    206
#
#                                                     KRT4  ...  ZYG11A  NRG1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...     0  ...      10   136
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   413  ...       0   264
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     0  ...       0    38
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   176  ...       0    16
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     0  ...       1    25
#
#                                                     RBMS3  VCPIP1  LINC02693  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       0         29
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      0     134         68
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0       0          0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      0       4          1
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0       0          0
#
#                                                     OR8B9P  NEAT1  ZDHHC23  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...       0     29        0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...       0    213        0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...       0     92        0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...       0      1        0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...       0    128        0
#
#                                                     ODAD2  Target
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       1
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      0       0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      0       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0       0
#
# [5 rows x 3001 columns]

# %% [markdown]
# # DIMENSIONALITY REDUCTION

# %%
# we rescale the data for the dimensionality reduction
df_dim_red = pd.DataFrame(StandardScaler().fit_transform(df_seq_HfiltNormT), columns=df_seq_HfiltNormT.columns, index=df_seq_HfiltNormT.index)

# %%
# first, we perform a PCA, with the number of dimensions chosen to explain at least 95% of the variance
pca = PCA()
pca_array = pca.fit_transform(df_dim_red)
pca_array_df = pd.DataFrame(pca_array, columns=[f'PC{i+1}' for i in range(pca_array.shape[1])], index=df_dim_red.index)
cumsum = np.cumsum(pca.explained_variance_ratio_)
plt.plot(cumsum)
nec_dimensions = np.argmax(cumsum >= 0.95)
plt.scatter(nec_dimensions, 0.95, color='red')
plt.plot([nec_dimensions, nec_dimensions], [0, 0.95], linestyle='--', color='black')
plt.plot([0, nec_dimensions], [0.95, 0.95], linestyle='--', color='black')
print(f"The number of dimensions needed to explain 95% of the variance is {nec_dimensions}")
# Out:
# The number of dimensions needed to explain 95% of the variance is 156

# %%
columns = [f'PC{i+1}' for i in range(nec_dimensions)] + ['Condition']
lower_dimensional_df_pca = add_target_column(pca_array_df, df_metaH_path, 'Condition', 'category_Normo')
lower_dimensional_df_pca
# Out:
#                                                           PC1        PC2  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  -2.849172  -5.641256
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   7.899027  10.434396
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  -0.497909  12.686548
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   4.081950   8.070230
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...   2.255481   2.840024
# ...                                                       ...        ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  -5.029623  -0.692542
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned.... -10.483137   9.072835
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  -3.681015  10.807696
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  -5.148520  -2.659664
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  -5.424451 -10.692700
#
#                                                          PC3        PC4  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  3.283657  -1.667505
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so... -8.601802  -1.923534
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort... -9.234080   3.214453
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort... -4.739527  -7.265787
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so... -4.790213  -1.587465
# ...                                                      ...        ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  0.471921   0.697539
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned.... -0.526084  11.323510
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so... -4.232734   5.482448
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  0.176754   1.404909
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  2.001473  -4.226961
#
#                                                           PC5        PC6  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...   1.135635  -7.009527
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  -6.832911   5.648019
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  -2.982438   3.115615
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort... -10.429683 -12.406240
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  13.384585   8.915837
# ...                                                       ...        ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  -4.912730  -5.934012
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned.... -11.529163  -5.013493
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...   3.476512  -2.294010
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  -1.671454  -4.645645
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...   0.223868  -2.223796
#
#                                                          PC7       PC8  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  4.770527  3.533012
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so... -2.703662  0.878815
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort... -6.355998 -0.371350
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  7.304108 -4.828556
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so... -7.123104 -5.381233
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  2.298884  1.506377
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned.... -3.475613  6.787753
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so... -3.331740  1.998145
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  0.249085  1.700167
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  3.547406 -4.445726
#
#                                                           PC9      PC10  ...  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  -1.392528  6.015874  ...
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  10.435058  3.384237  ...
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...   1.712405  3.502314  ...
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   4.779845  7.469944  ...
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...   2.694777 -0.280285  ...
# ...                                                       ...       ...  ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  -2.694541  1.711191  ...
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  -8.524545  2.379595  ...
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  -6.198678  1.467658  ...
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  -0.822144  0.593615  ...
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...   1.106223 -0.563422  ...
#
#                                                        PC174     PC175  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  1.436432  0.582227
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  0.276856  1.034472
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  0.815947  0.561735
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  0.034216 -0.631742
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so... -0.167988 -1.450697
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  0.006673  1.125541
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  0.442726 -0.924479
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so... -0.219549 -0.043041
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  5.684210  1.257320
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s... -3.045847  7.018578
#
#                                                         PC176      PC177  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  -0.365204   1.104006
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   0.660339   0.020258
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  -0.158756  -0.082145
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   0.299086   0.758739
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  -0.446048   1.015894
# ...                                                       ...        ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....   1.848602  -0.386280
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  -0.165619  -0.168816
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...   0.422946   1.048135
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  -1.070468   7.220301
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  16.644356  17.039755
#
#                                                         PC178     PC179  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  -0.914003 -0.594664
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  -0.538893  0.231273
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  -0.001870  0.665049
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   0.286494  0.005387
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  -0.957183  0.949954
# ...                                                       ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....   0.365990  1.526764
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  -0.818704  0.660295
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  -0.346230  0.364162
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  23.627545 -6.052572
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  -5.779063  2.059250
#
#                                                        PC180     PC181  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s... -0.569110  0.048935
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so... -0.008734 -0.086203
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort... -0.069882  0.001407
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort... -0.274822 -0.013367
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so... -0.863188 -0.118320
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  0.003624 -0.048710
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  0.626414  0.053303
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so... -0.434468 -0.010178
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  5.841612  0.172670
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s... -1.668797 -0.019661
#
#                                                            PC182  Target
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  7.273971e-15       1
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  7.273971e-15       0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  7.273971e-15       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  7.273971e-15       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  7.273971e-15       0
# ...                                                          ...     ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  7.273971e-15       1
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  7.273971e-15       1
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  7.273971e-15       0
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  7.273971e-15       1
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  7.273971e-15       1
#
# [182 rows x 183 columns]

# %%
# now, we use umap. since it's harder to estimate the explained variance, we use a heuristic: the number of components will be the same as in PCA
reducer = umap.UMAP(n_components=nec_dimensions, n_neighbors=50) #qualitatively, 50 neighbors seemed to work well for out scope
embedding = reducer.fit_transform(df_dim_red)
columns = [f'UMAP{i+1}' for i in range(embedding.shape[1])]
umap_embedding_df = pd.DataFrame(embedding, columns=columns, index=df_dim_red.index)
lower_dimensional_df_umap = add_target_column(umap_embedding_df, df_metaH_path, 'Condition', 'category_Normo')

lower_dimensional_df_umap
# Out:
#                                                        UMAP1     UMAP2  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  6.599414  2.041154
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  6.401522  2.158103
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  6.497538  2.268611
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  6.496990  2.266438
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  6.584734  2.321193
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  6.794158  1.630927
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  6.893013  1.755967
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  6.896239  2.152732
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  6.716993  1.946227
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  6.278479  2.195412
#
#                                                        UMAP3     UMAP4  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  6.971325  6.526663
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  6.851039  6.516154
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  6.864427  6.560658
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  6.904742  6.548445
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  6.908044  6.565454
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  7.039256  6.546917
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  7.037914  6.583755
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  6.924488  6.674103
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  6.904266  6.573938
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  7.066445  6.371006
#
#                                                        UMAP5     UMAP6  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  6.551040  6.963095
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  6.349733  6.920352
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  6.495485  6.943682
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  6.481297  6.918332
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  6.438148  7.000387
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  6.718563  6.990416
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  6.710884  7.135384
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  6.432017  7.098990
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  6.511055  6.944049
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  6.462858  6.934944
#
#                                                        UMAP7     UMAP8  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  7.481047  2.793933
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  7.525762  2.899341
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  7.604836  2.912123
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  7.712195  2.875452
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  7.707363  2.894293
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  7.653598  3.005357
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  7.725417  2.910776
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  7.756317  2.931487
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  7.555462  2.894476
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  7.559951  2.655016
#
#                                                        UMAP9    UMAP10  ...  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  3.946124  4.660880  ...
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  4.089966  4.839721  ...
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  4.018628  4.794371  ...
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  3.928542  4.751987  ...
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  4.079663  4.842476  ...
# ...                                                      ...       ...  ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  3.939380  4.698252  ...
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  3.869744  4.676216  ...
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  3.968352  4.867907  ...
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  3.894452  4.731716  ...
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  4.151267  4.768224  ...
#
#                                                      UMAP148   UMAP149  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  4.630562  5.222187
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  4.733392  5.197639
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  4.658091  5.256208
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  4.540979  5.094913
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  4.569977  5.301090
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  4.736716  5.180708
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  4.727883  5.328930
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  4.604428  5.523459
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  4.703523  5.239071
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  4.541513  4.861230
#
#                                                      UMAP150   UMAP151  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  4.809266  3.878228
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  4.826172  4.008769
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  4.844611  4.032125
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  4.745440  3.867828
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  4.575099  3.758924
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  4.791666  3.948495
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  4.812093  3.891200
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  4.923272  3.817444
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  4.922743  3.991744
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  4.591967  3.698632
#
#                                                      UMAP152   UMAP153  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  5.473543  5.470379
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  5.407741  5.499208
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  5.487905  5.678005
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  5.422306  5.577425
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  5.283079  5.736968
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  5.431626  5.445960
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  5.254351  5.707709
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  5.304619  6.089904
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  5.350221  5.566374
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  5.313207  5.255930
#
#                                                      UMAP154   UMAP155  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  3.313826  3.998315
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  3.389252  3.761586
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  3.430829  3.952732
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  3.434580  3.794938
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  3.447131  3.979645
# ...                                                      ...       ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  3.448154  3.778841
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  3.418511  4.036804
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  3.368230  4.035885
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  3.456317  3.777801
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  3.326467  3.666548
#
#                                                      UMAP156  Target
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...  6.297352       1
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...  6.614126       0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  6.694474       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...  6.621409       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...  6.589424       0
# ...                                                      ...     ...
# output.STAR.PCRPlate4H10_Normoxia_S210_Aligned....  6.505902       1
# output.STAR.PCRPlate4H11_Normoxia_S214_Aligned....  6.560819       1
# output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.so...  6.823097       0
# output.STAR.PCRPlate4H7_Normoxia_S205_Aligned.s...  6.681440       1
# output.STAR.PCRPlate4H9_Normoxia_S236_Aligned.s...  6.204308       1
#
# [182 rows x 157 columns]

# %% [markdown]
# nota: AN GPTL4 PGK1 SONO IMPORTNTI VERMNETE, L HA DETTO LEI

# %%
def load_dataset(dataset):
    X = dataset.drop(columns=['Target'])
    y = dataset['Target']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
    kfold = KFold(n_splits=5, shuffle=True, random_state=123)
    return X, y, X_train, X_test, y_train, y_test, kfold

def run_xgboost(dataset):
    X, y, X_train, X_test, y_train, y_test, kfold = load_dataset(dataset)
    retval = {}

    # Define the parameter grid
    param_grid = {
        'max_depth': range(3, 10),
        'learning_rate': np.linspace(0.1, 1, 10),
        'n_estimators': range(10, 110, 10),
        'gamma': np.linspace(0, 0.5, 5),
        'subsample': np.linspace(0.5, 1, 6),
        'colsample_bytree': np.linspace(0.5, 1, 6),
        'min_child_weight': range(1, 6),
        'scale_pos_weight': range(1, 6)
    }

    xg_cl = XGBClassifier()


    # Instantiate RandomizedSearchCV
    random_search = RandomizedSearchCV(xg_cl, param_distributions=param_grid, n_iter=50, scoring='accuracy',
                                        n_jobs=-1, cv=kfold, random_state=123)

    # Fit the model
    random_search.fit(X, y)

    # Print/return the best parameters
    retval['parameters'] = random_search.best_params_
    # to ask filippo & giuseppe: do we need to return also the best score and best estimator?
    # print(random_search.best_params_)
    # print(random_search.best_score_)
    # print(random_search.best_estimator_)

    #Now we implement the best model
    xgb_optm = xgb.XGBClassifier(objective='binary:logistic', **random_search.best_params_)

    # Train the model
    xgb_optm.fit(X_train, y_train)

    # Make predictions on the test set
    predictions = xgb_optm.predict(X_test)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, predictions)
    retval['accuracy'] = accuracy
    #print("Accuracy:", accuracy)

    # Create confusion matrix
    conf_matrix = confusion_matrix(y_test, predictions)
    retval['confusion_matrix'] = conf_matrix

    retval['model'] = xgb_optm
    
    return retval

def plot_confusion_matrix(model):
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(model['confusion_matrix'], annot=True, fmt="d", cmap="Blues", cbar=False)
    plt.xlabel("Predicted labels")
    plt.ylabel("True labels")
    plt.title("Confusion Matrix")
    plt.show()

def plot_feature_importance(model):
    # Plot feature importance
    plt.figure(figsize=(10, 6))
    xgb.plot_importance(model['model'], max_num_features=10)  # You can adjust max_num_features as per your preference
    plt.title("Feature Importance")
    plt.show()

# %%
merged_xgboost = run_xgboost(merged)
print(f"Accuracy: {merged_xgboost['accuracy']}")
plot_confusion_matrix(merged_xgboost)
plot_feature_importance(merged_xgboost)
# Out:
# Accuracy: 0.972972972972973

# %%
pca_xgboost = run_xgboost(lower_dimensional_df_pca)
print(f"Accuracy: {pca_xgboost['accuracy']}")
plot_confusion_matrix(pca_xgboost)
plot_feature_importance(pca_xgboost)
# Out:
# Accuracy: 0.8378378378378378

# %%
umap_xgboost = run_xgboost(lower_dimensional_df_umap)
print(f"Accuracy: {umap_xgboost['accuracy']}")
plot_confusion_matrix(umap_xgboost)
plot_feature_importance(umap_xgboost)
# Out:
# Accuracy: 1.0

# %%
def run_kneighbors(dataset):
    X, y, X_train, X_test, y_train, y_test, kfold = load_dataset(dataset)
    retval = {}
    param_grid = {
        'n_neighbors': range(1, 20),
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan', 'minkowski']
    }

    knn = KNeighborsClassifier()

    # Instantiate Gridsearch
    grid_search = GridSearchCV(knn, param_grid=param_grid, scoring='accuracy',
                            n_jobs=-1, cv=kfold)

    # Fit the model
    grid_search.fit(X, y)

    # Print the best parameters
    retval['parameters'] = grid_search.best_params_
    # print(grid_search.best_params_)
    # print(grid_search.best_score_)
    # print(grid_search.best_estimator_)

    knn_optm = KNeighborsClassifier(**grid_search.best_params_)

    # Train the KNN classifier
    knn_optm.fit(X_train, y_train)

    # Make predictions on the test set
    knn_predictions = knn_optm.predict(X_test)

    # Calculate accuracy
    knn_accuracy = accuracy_score(y_test, knn_predictions)
    retval['accuracy'] = knn_accuracy

    # Perform k-fold cross-validation
    cv_results = cross_val_score(knn_optm, X, y, cv=kfold, scoring='accuracy')
    # what to do with cross validation accuracy??
    # Print the results
    print('Accuracy:', cv_results)
    print('Average accuracy:', cv_results.mean())

    # Create confusion matrix
    conf_matrix = confusion_matrix(y_test, knn_predictions)
    retval['confusion_matrix'] = conf_matrix

    return retval

# %%
merged_kneighbors = run_kneighbors(merged)
print(f"Accuracy: {merged_kneighbors['accuracy']}")
plot_confusion_matrix(merged_kneighbors)
pca_kneighbors = run_kneighbors(lower_dimensional_df_pca)
print(f"Accuracy: {pca_kneighbors['accuracy']}")
plot_confusion_matrix(pca_kneighbors)
umap_kneighbors = run_kneighbors(lower_dimensional_df_umap)
print(f"Accuracy: {umap_kneighbors['accuracy']}")
plot_confusion_matrix(umap_kneighbors)
# Out:
# Accuracy: [1.         0.94594595 0.94444444 0.94444444 1.        ]
# Average accuracy: 0.9669669669669669
# Accuracy: 1.0
# Accuracy: [0.81081081 0.75675676 0.91666667 0.88888889 0.91666667]
# Average accuracy: 0.8579579579579579
# Accuracy: 0.8108108108108109
# Accuracy: [1.         0.94594595 0.80555556 0.94444444 0.97222222]
# Average accuracy: 0.9336336336336337
# Accuracy: 1.0

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot
scatter = ax.scatter(X['ANGPTL4'], X['DDIT4'], X['EGLN3'], c=y, cmap='coolwarm', edgecolor='k', s=150)

# Set labels and title
ax.set_xlabel('ANGPTL4')
ax.set_ylabel('DDIT4')
ax.set_zlabel('EGLN3')
ax.set_title('3D Scatter plot of two genes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 5
#       2 ax = fig.add_subplot(111, projection='3d')
#       4 # Scatter plot
# ----> 5 scatter = ax.scatter(X['ANGPTL4'], X['DDIT4'], X['EGLN3'], c=y, cmap='coolwarm', edgecolor='k', s=150)
#       7 # Set labels and title
#       8 ax.set_xlabel('ANGPTL4')
#
# NameError: name 'X' is not defined

# %%
def run_logistic_regression(dataset):
    X, y, X_train, X_test, y_train, y_test, kfold = load_dataset(dataset)

    # Define the parameter grid
    param_grid = {
        'penalty': ['l1', 'l2', 'elasticnet', 'none'],
        'C': np.linspace(0.1, 1, 10),
        'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']}

    log_reg = LogisticRegression()

    random_search = RandomizedSearchCV(log_reg, param_distributions=param_grid, n_iter=50, scoring='accuracy',
                                        n_jobs=-1, cv=kfold, random_state=123)


    # Fit the model

    random_search.fit(X, y)

    # Print the best parameters
    print(random_search.best_params_)
    print(random_search.best_score_)
    print(random_search.best_estimator_)
# Out:
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# {'solver': 'liblinear', 'penalty': 'l1', 'C': 0.5}
# 0.9945945945945945
# LogisticRegression(C=0.5, penalty='l1', solver='liblinear')
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 160 fits failed out of a total of 250.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'elasticnet', 'l1'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l1', 'l2', 'elasticnet'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'elasticnet', 'l2', 'l1'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 9 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'elasticnet', 'l1', 'l2'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l1', 'elasticnet', 'l2'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 75, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'l1', 'elasticnet'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1182, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/edoardoghirardo/miniconda/envs/edo/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.97837838        nan 0.96726727        nan 0.96726727
#         nan        nan 0.98903904        nan 0.99459459 0.97837838
#  0.98918919 0.96726727 0.96726727        nan 0.96726727        nan
#         nan        nan        nan 0.96726727 0.97282282        nan
#  0.96726727        nan        nan 0.97282282 0.96726727        nan
#         nan        nan        nan        nan 0.97837838        nan
#  0.96726727        nan        nan        nan 0.96726727        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan]
#   warnings.warn(

# %%
# Instantiate the Logistic Regression classifier
lr_optm = LogisticRegression(**random_search.best_params_)

# Train the model
lr_optm.fit(X_train, y_train)

# Make predictions on the test set
log_reg_predictions = lr_optm.predict(X_test)

# Calculate accuracy
log_reg_accuracy = accuracy_score(y_test, log_reg_predictions)

# Print the accuracy
print("Accuracy:", log_reg_accuracy)

# Perform k-fold cross-validation
cv_results = cross_val_score(lr_optm, X, y, cv=kfold, scoring='accuracy')

# Print the results
print('Accuracy:', cv_results)
print('Average accuracy:', cv_results.mean())

# Create confusion matrix
conf_matrix = confusion_matrix(y_test, log_reg_predictions)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy: 1.0
# Accuracy: [1.         0.97297297 0.97222222 1.         1.        ]
# Average accuracy: 0.989039039039039

# %%
# Print classification report
print("Classification Report:")
print(classification_report(y_test, log_reg_predictions))

# Plot ROC curve
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# Get predicted probabilities
log_reg_probs = lr_optm.predict_proba(X_test)[:, 1]

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, log_reg_probs)
auc = roc_auc_score(y_test, log_reg_probs)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend()
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        17
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37

# %% [markdown]
# RF

# %%
# We start by estimating the most important hyperparameter: the number of trees
param_range = np.arange(1, 100, 10)
train_scores, test_scores = validation_curve(
    RandomForestClassifier(random_state=42),
    X_train, y_train,
    param_name='n_estimators',
    param_range=param_range,
    cv=5,
    scoring='accuracy'
)
# Plot the learning curve
# Find the optimal parameter
optimal_param = param_range[np.argmax(np.mean(test_scores, axis=1))]

# Plot the learning curve with enhanced appearance
plt.figure(figsize=(10, 6))
plt.plot(param_range, np.mean(train_scores, axis=1), label='Training score', marker='o', linestyle='-')
plt.plot(param_range, np.mean(test_scores, axis=1), label='Cross-validation score', marker='o', linestyle='-')
plt.axvline(x=optimal_param, color='red', linestyle='--', label='Optimal Parameter')
plt.title('Validation Curve for Random Forest')
plt.xlabel('Number of Trees (n_estimators)')
plt.ylabel('Accuracy')
plt.xticks(param_range)
plt.legend()
plt.grid(True)
plt.show()

# %%
# We proceed to do a grid search to find the optimal hyperparameters with cross-validation
param_grid = {
    'max_depth': np.arange(1, 10, 1),
    'min_samples_split': np.arange(2, 10, 1),
    'min_samples_leaf': np.arange(1, 10, 1)
}
grid_search = GridSearchCV(RandomForestClassifier(n_estimators = 21, random_state=42), param_grid, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)
# Get the best hyperparameters
best_params = grid_search.best_params_
print('Best hyperparameters:', best_params)
# Out:
# Best hyperparameters: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
# Train the model with the best hyperparameters
rf_optm = RandomForestClassifier(n_estimators=21, random_state=42, **best_params)
rf_optm.fit(X_train, y_train)
# Predict y
y_pred = rf_optm.predict(X_test)

# %%
# Now evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0

# %%
# Confusion matrix
# Create confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted labels")
plt.ylabel("True labels")
plt.title("Confusion Matrix")
plt.show()

# %%
# Classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        17
#
#     accuracy                           1.00        37
#    macro avg       1.00      1.00      1.00        37
# weighted avg       1.00      1.00      1.00        37

# %%
# Initialize lists to store evaluation scores
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Create subplots for confusion matrices and learning curves
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(15, 30))

# Iterate over folds
for i, (train_index, test_index) in enumerate(kfold.split(X)):
    # Split data into training and testing sets
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Create a Random Forest Classifier model
    rf = RandomForestClassifier(n_estimators=21, random_state=42, **best_params)

    # Fit the model to the training data
    rf.fit(X_train, y_train)

    # Predict on the testing data
    y_pred = rf.predict(X_test)

    # Calculate evaluation scores
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Append scores to lists
    accuracy_scores.append(accuracy)
    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)

    # Print evaluation scores for each fold
    print(f"\nFold {i+1} Evaluation Scores:")
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1)

    # Plot confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', cbar=False, ax=axes[i, 0])
    axes[i, 0].set_xlabel('Predicted')
    axes[i, 0].set_ylabel('Actual')
    axes[i, 0].set_title(f'Fold {i+1}: Confusion Matrix')

    # Plot learning curve
    train_sizes, train_scores, test_scores = learning_curve(rf, X_train, y_train, cv=kf, n_jobs=-1, train_sizes=np.linspace(0.1, 1.0, 10), scoring='accuracy')
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    axes[i, 1].fill_between(train_sizes, train_scores_mean - train_scores_std, train_scores_mean + train_scores_std, alpha=0.1, color="r")
    axes[i, 1].fill_between(train_sizes, test_scores_mean - test_scores_std, test_scores_mean + test_scores_std, alpha=0.1, color="g")
    axes[i, 1].plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
    axes[i, 1].plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")
    axes[i, 1].set_xlabel("Training examples")
    axes[i, 1].set_ylabel("Score")
    axes[i, 1].set_title(f"Learning Curve (Fold {i+1})")
    axes[i, 1].legend(loc="best")
    axes[i, 1].grid()

plt.tight_layout()
plt.show()

# Print mean evaluation scores across all folds
print("\nMean Evaluation Scores Across Folds:")
print("Mean Accuracy:", np.mean(accuracy_scores))
print("Mean Precision:", np.mean(precision_scores))
print("Mean Recall:", np.mean(recall_scores))
print("Mean F1-score:", np.mean(f1_scores))
# Out:
# Fold 1 Evaluation Scores:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#
# Fold 2 Evaluation Scores:
# Accuracy: 0.918918918918919
# Precision: 0.92
# Recall: 0.9583333333333334
# F1-score: 0.9387755102040817
#
# Fold 3 Evaluation Scores:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
#
# Fold 4 Evaluation Scores:
# Accuracy: 0.9722222222222222
# Precision: 0.9230769230769231
# Recall: 1.0
# F1-score: 0.9600000000000001
#
# Fold 5 Evaluation Scores:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# Mean Evaluation Scores Across Folds:
# Mean Accuracy: 0.9782282282282282
# Mean Precision: 0.9686153846153847
# Mean Recall: 0.9916666666666668
# Mean F1-score: 0.9797551020408164

# %%
# Create a Random Forest Classifier model with the best parameters and enable OOB scoring
rf_OOB = RandomForestClassifier(n_estimators=21, random_state=42, **best_params, oob_score=True)
# Fit the model to the entire dataset
rf_OOB.fit(X, y)
# Access the OOB score
oob_accuracy = rf_OOB.oob_score_
# Print OOB accuracy
print("Out-of-Bag (OOB) Accuracy:", oob_accuracy)
# Out:
# Out-of-Bag (OOB) Accuracy: 0.9615384615384616

# %% [markdown]
# SVM

# %% [markdown]
# Da modificare Filippo

# %% [markdown]
# Pipeline for model comparison

# %%
model_pipleline = []
model_pipleline.append(('RF', rf_optm))
# model_pipleline.append(('SVM', svm_optm))
model_pipleline.append(('KNN', knn_optm))
model_pipleline.append(('LR', lr_optm))
model_pipleline.append(('XGBoost', xgb_optm))
# model_pipleline.append(('NN', ?(**best_params_nn)))

# %%
model_names = ['RF', 'SVM', 'KNN', 'LR', 'XGBoost', 'NN']
# Create a metric of comparison for the models
acc_list = []
cm_list = []
prec_list_n = []
rec_list_n = []
f1_list_n = []

auc_list = []
imp_list = []

for model in model_pipleline:
    # Use the fitted models above to predict on the test data
    y_pred = model[1].predict(X_test)
  
    # Create confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)
    cm_list.append(conf_matrix)

    # Accuracy
    acc = accuracy_score(y_test, y_pred)
    acc_list.append(f"{acc.mean().round(3)}±{acc.std().round(3)}")
    # Precision
    prec = precision_score(y_test, y_pred)
    prec_list_n.append(f"{prec.mean().round(3)}±{prec.std().round(3)}")
    # Recall
    rec = recall_score(y_test, y_pred)
    rec_list_n.append(f"{rec.mean().round(3)}±{rec.std().round(3)}")
    # F1 score
    f1 = f1_score(y_test, y_pred)
    f1_list_n.append(f"{f1.mean().round(3)}±{f1.std().round(3)}")

# %%
# SEQUENTIAL NN WITH KERAS

def create_nn_model(dataset, epochs):
    X, y, X_train, X_test, y_train, y_test, kfold = load_dataset(dataset)
    retval = {}
    nn_model = tf.keras.models.Sequential()
    nn_model.add(tf.keras.layers.Flatten(input_shape=(X_train.shape[1],)))
    nn_model.add(tf.keras.layers.Dense(128, activation='relu'))
    nn_model.add(tf.keras.layers.Dense(128, activation='relu'))
    nn_model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    nn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.01, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False, start_from_epoch=0)

    nn_model.fit(X_train, y_train, epochs=epochs)

    val_loss, val_acc = nn_model.evaluate(X_test, y_test)
    
    # print(f"Validation loss: {val_loss}, Validation accuracy: {val_acc}")
    retval['model'] = nn_model
    retval['accuracy'] = val_acc

    return retval

# %%
nn = create_nn_model(merged, 100)
print(nn['accuracy'])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 2ms/step - loss: 238.1044 - accuracy: 0.6828
# Epoch 2/100
# 5/5 [==============================] - 0s 1ms/step - loss: 39.6312 - accuracy: 0.8828
# Epoch 3/100
# 5/5 [==============================] - 0s 1ms/step - loss: 29.0891 - accuracy: 0.9103
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 14.2767 - accuracy: 0.9448
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 6/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 7/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.3801e-36 - accuracy: 1.0000
# Epoch 8/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3033 - accuracy: 0.9931
# Epoch 9/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 10/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 11/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 12/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 13/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 14/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 15/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 16/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 17/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 18/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 19/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 20/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 21/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 22/100
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 23/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 24/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 25/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 26/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 27/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 28/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 29/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 30/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 31/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 32/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 33/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 34/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 35/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 36/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 37/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 38/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 39/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 40/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 41/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 42/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 43/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 44/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 45/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 46/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 47/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 48/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 49/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 50/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 51/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 52/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 53/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 54/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 55/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 56/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 57/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 58/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 59/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 60/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 61/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 62/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 64/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 65/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 66/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 67/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 68/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 69/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 92/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 93/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 94/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 96/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 98/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 99/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# Epoch 100/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# 2/2 [==============================] - 0s 2ms/step - loss: 13.2128 - accuracy: 0.9459
# 0.9459459185600281
