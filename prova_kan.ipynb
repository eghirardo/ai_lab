# %%
# !pip install imodelsx
# Out:
# Requirement already satisfied: imodelsx in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (1.0.3)
# Requirement already satisfied: datasets in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (2.16.1)
# Requirement already satisfied: dict-hash in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (1.1.36)
# Requirement already satisfied: imodels in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (1.4.3)
# Requirement already satisfied: langchain in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (0.1.17)
# Requirement already satisfied: numpy in /Users/filipporonzino/.local/lib/python3.11/site-packages (from imodelsx) (1.26.4)
# Requirement already satisfied: pandas in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (2.1.4)
# Requirement already satisfied: scikit-learn in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (1.3.0)
# Requirement already satisfied: scipy in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (1.13.0)
# Requirement already satisfied: spacy in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (3.7.4)
# Requirement already satisfied: torch in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (2.1.0.post100)
# Requirement already satisfied: tqdm in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (4.66.1)
# Requirement already satisfied: transformers[torch]>=4.23.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodelsx) (4.28.1)
# Requirement already satisfied: filelock in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (0.20.2)
# Requirement already satisfied: packaging>=20.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (2023.10.3)
# Requirement already satisfied: requests in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from transformers[torch]>=4.23.1->imodelsx) (0.13.2)
# Requirement already satisfied: typing-extensions in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from torch->imodelsx) (4.9.0)
# Requirement already satisfied: sympy in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from torch->imodelsx) (1.12)
# Requirement already satisfied: networkx in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from torch->imodelsx) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from torch->imodelsx) (3.1.3)
# Requirement already satisfied: fsspec in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from torch->imodelsx) (2023.10.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (11.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (0.3.7)
# Requirement already satisfied: xxhash in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (2.0.2)
# Requirement already satisfied: multiprocess in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (0.70.15)
# Requirement already satisfied: aiohttp in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from datasets->imodelsx) (3.9.0)
# Requirement already satisfied: deflate-dict>=1.0.8 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from dict-hash->imodelsx) (1.0.11)
# Requirement already satisfied: support-developer>=1.0.4 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from dict-hash->imodelsx) (1.0.5)
# Requirement already satisfied: matplotlib in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodels->imodelsx) (3.8.0)
# Requirement already satisfied: mlxtend>=0.18.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from imodels->imodelsx) (0.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from pandas->imodelsx) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from pandas->imodelsx) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from pandas->imodelsx) (2023.4)
# Requirement already satisfied: joblib>=1.1.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from scikit-learn->imodelsx) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from scikit-learn->imodelsx) (3.2.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (2.0.25)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (0.6.5)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (0.0.36)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (0.1.50)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (0.1.54)
# Requirement already satisfied: pydantic<3,>=1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (2.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langchain->imodelsx) (8.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (6.4.0)
# Requirement already satisfied: setuptools in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from spacy->imodelsx) (3.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->imodelsx) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->imodelsx) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->imodelsx) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->imodelsx) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from aiohttp->datasets->imodelsx) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->imodelsx) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain->imodelsx) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain->imodelsx) (2.0)
# Requirement already satisfied: language-data>=1.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->imodelsx) (1.2.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain->imodelsx) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from matplotlib->imodels->imodelsx) (2.4.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1->langchain->imodelsx) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=1->langchain->imodelsx) (2.18.2)
# Requirement already satisfied: six>=1.5 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->imodelsx) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from requests->transformers[torch]>=4.23.1->imodelsx) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from requests->transformers[torch]>=4.23.1->imodelsx) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from requests->transformers[torch]>=4.23.1->imodelsx) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from requests->transformers[torch]>=4.23.1->imodelsx) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy->imodelsx) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy->imodelsx) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy->imodelsx) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy->imodelsx) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from jinja2->torch->imodelsx) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from sympy->torch->imodelsx) (1.3.0)
# Requirement already satisfied: marisa-trie>=0.7.7 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->imodelsx) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/filipporonzino/anaconda3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain->imodelsx) (1.0.0)

# %%
import imodelsx.kan
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import torch as th

# %%
# Load the dataset
df_seq_pathHFiltNorm = '../ai_lab/SmartSeq/HCC1806_SmartS_Filtered_Normalised_3000_Data_train.txt'
df_seq_HFiltNorm = pd.read_csv(df_seq_pathHFiltNorm, delimiter=' ')
df_seq_HfiltNormT = df_seq_HFiltNorm.T
#we now add the target variable
df_metaH_path = '../ai_lab/SmartSeq/HCC1806_SmartS_MetaData.tsv'
df_metaH = pd.read_csv(df_metaH_path, delimiter='\t')
df_metaH.set_index('Filename', inplace=True)

def add_target_column(data, metadata_path, target_column_name, target_category):
    df_meta = pd.read_csv(metadata_path, delimiter='\t')
    df_meta.set_index('Filename', inplace=True)
    merged_transition = pd.merge(data, df_meta[target_column_name], left_index=True, right_index=True)
    dummy_variables = pd.get_dummies(merged_transition[target_column_name], prefix='category').astype('int')
    
    # Set the target category to 1 and the others to 0
    dummy_variables['Target'] = dummy_variables[target_category]
    dummy_variables.drop(columns=[col for col in dummy_variables.columns if col != 'Target'], inplace=True)
    
    merged_data = pd.concat([merged_transition, dummy_variables], axis=1)
    merged_data.drop(columns=[target_column_name], inplace=True)
    return merged_data
merged = add_target_column(df_seq_HfiltNormT, df_metaH_path, 'Condition', 'category_Normo')

# %%
merged.head()
# Out:
#                                                     DDIT4  ANGPTL4  CALML5  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       48       0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   8739     2101      55
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...  13098    14032       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   2880      356       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...   7777     5661    4383
#
#                                                     KRT14  CCNB1  IGFBP3  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    321    298      82
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...     96   1824    1938
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0   1616     247
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   6211      3    3430
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0    145    4618
#
#                                                     AKR1C2  KRT6A  NDRG1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...    6250    634      0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      62      0    522
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     430    907    348
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      79   1953    592
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     246     85    206
#
#                                                     KRT4  ...  ZYG11A  NRG1  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...     0  ...      10   136
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...   413  ...       0   264
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...     0  ...       0    38
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...   176  ...       0    16
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...     0  ...       1    25
#
#                                                     RBMS3  VCPIP1  LINC02693  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       0         29
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      0     134         68
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0       0          0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      0       4          1
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0       0          0
#
#                                                     OR8B9P  NEAT1  ZDHHC23  \
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...       0     29        0
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...       0    213        0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...       0     92        0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...       0      1        0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...       0    128        0
#
#                                                     ODAD2  Target
# output.STAR.PCRPlate1G12_Normoxia_S32_Aligned.s...      0       1
# output.STAR.PCRPlate1G1_Hypoxia_S102_Aligned.so...      0       0
# output.STAR.PCRPlate1G2_Hypoxia_S2_Aligned.sort...      0       0
# output.STAR.PCRPlate1G3_Hypoxia_S7_Aligned.sort...      0       0
# output.STAR.PCRPlate1G4_Hypoxia_S107_Aligned.so...      0       0
#
# [5 rows x 3001 columns]

# %%
# Split X and y using ndarray
X = merged.iloc[:, :-1].values
y = merged.iloc[:, -1].values
print(X.shape, y.shape)
print(type(X), type(y))
# Out:
# (182, 3000) (182,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
# Model KAN
model = imodelsx.kan.KANClassifier(hidden_layer_size=3, device='cpu', regularize_activation=1.0, regularize_entropy=1.0)
model.fit(X, y)
y_pred = model.predict(X)

accuracy_score(y, y_pred)
# Out:
#   3%|▎         | 3/100 [00:00<00:05, 18.03it/s]
# Early stopping
# 0.521978021978022

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(model, X, y, cv=5, scoring='accuracy'))
# Out:
#   3%|▎         | 3/100 [00:00<00:04, 23.01it/s]
# Early stopping
# 100%|██████████| 100/100 [00:03<00:00, 29.86it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.35it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.02it/s]
# 100%|██████████| 100/100 [00:03<00:00, 29.75it/s]
# [0.54054054 0.54054054 0.63888889 0.58333333 0.52777778]
